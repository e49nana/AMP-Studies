# %% [markdown]
# # Optimisation 1D
#
# **Module :** `optimization.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch2-differentialrechnung'))

# %% [markdown]
# ## Newton, gradient descent, section dorée

# %%
from optimization import *
import numpy as np
f = lambda x: (x-2)**2 + 1
for r in [newton_optimisation(f, 5.0), gradient_descent(f, 5.0, 0.1), golden_section(f, -1, 6)]:
    print(f'{r.methode:20s}: x*={r.x:.6f}, {r.iterations} it.')
