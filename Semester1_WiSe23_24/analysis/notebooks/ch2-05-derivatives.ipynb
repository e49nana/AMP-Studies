# %% [markdown]
# # Dérivées
#
# **Module :** `derivatives.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch2-differentialrechnung'))

# %% [markdown]
# ## Différences finies et règles

# %%
from derivatives import *
import numpy as np
exact = np.cos(1.0)
for nom, fn in [('progressive', derivee_progressive), ('centrée', derivee_centree)]:
    print(f'{nom}: {fn(np.sin, 1.0):.15f} err={abs(fn(np.sin,1.0)-exact):.2e}')
