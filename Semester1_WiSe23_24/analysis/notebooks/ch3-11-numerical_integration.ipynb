# %% [markdown]
# # Intégration numérique
#
# **Module :** `numerical_integration.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch3-integralrechnung'))

# %% [markdown]
# ## Trapèzes O(h²) vs Simpson O(h⁴)

# %%
from numerical_integration import *
import numpy as np
for n in [4, 16, 64]:
    print(f'n={n}: trap={trapezes(np.exp,0,1,n):.10f} simp={simpson(np.exp,0,1,n):.10f}')
