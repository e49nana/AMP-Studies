# %% [markdown]
# # Systèmes d'EDO
#
# **Module :** `ode_systems.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch4-ode'))

# %% [markdown]
# ## Portraits de phase, Lotka-Volterra

# %%
from ode_systems import *
import numpy as np
f = oscillateur_harmonique(1.0)
t, y = rk4_systeme(f, 0, np.array([1.0, 0.0]), 10, 0.01)
print(f'Oscillateur: y(2π) = {y[int(2*np.pi/0.01)]}')
