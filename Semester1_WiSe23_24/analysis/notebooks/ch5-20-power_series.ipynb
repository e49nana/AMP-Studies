# %% [markdown]
# # Séries entières
#
# **Module :** `power_series.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch5-spezielle-funktionen'))

# %% [markdown]
# ## Rayon de convergence

# %%
from power_series import *
import numpy as np
c = coeffs_ln1px(100)
print(f'ln(2) par série = {evaluer_serie(c, np.array([1.0]))[0]:.10f}')
print(f'ln(2) exact     = {np.log(2):.10f}')
