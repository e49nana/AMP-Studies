# %% [markdown]
# # Runge-Kutta
#
# **Module :** `ode_runge_kutta.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch4-ode'))

# %% [markdown]
# ## RK2 et RK4 — le couteau suisse

# %%
from ode_runge_kutta import *
import numpy as np
for nom, m in [('Euler', euler), ('RK2', rk2_heun), ('RK4', rk4)]:
    t, y = m(lambda t,y: -y, 0, 1, 3, 0.1)
    print(f'{nom:5s}: y(3)={y[-1]:.12f} err={abs(y[-1]-np.exp(-3)):.2e}')
