# %% [markdown]
# # Sommes de Riemann
#
# **Module :** `riemann_sums.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch3-integralrechnung'))

# %% [markdown]
# ## Construction de l'intégrale

# %%
from riemann_sums import *
import numpy as np
for n in [10, 100, 1000]:
    print(f'n={n}: milieu={riemann_milieu(lambda x: x**2, 0, 1, n):.8f}')
