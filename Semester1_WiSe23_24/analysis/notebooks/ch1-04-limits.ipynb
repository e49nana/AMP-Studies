# %% [markdown]
# # Limites
#
# **Module :** `limits.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch1-folgen-reihen'))

# %% [markdown]
# ## Limites classiques et formes indéterminées

# %%
from limits import *
for nom, val, exact in limites_classiques():
    print(f'{nom:30s} ≈ {val:.6f} (exact: {exact})')
