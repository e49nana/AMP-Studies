# %% [markdown]
# # Kurvendiskussion
#
# **Module :** `curve_analysis.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch2-differentialrechnung'))

# %% [markdown]
# ## Analyse complète : zéros, extrema, inflexion

# %%
from curve_analysis import *
f = lambda x: x**3 - 3*x + 1
kd = analyser(f, -3, 3)
for x0, y0, typ in kd.extrema:
    print(f'{typ} en x={x0:.4f}, f(x)={y0:.4f}')
