# %% [markdown]
# # Séries
#
# **Module :** `series.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch1-folgen-reihen'))

# %% [markdown]
# ## Séries et critères de convergence

# %%
from series import *
import numpy as np
print(f'Σ1/k² = {sommes_partielles(serie_riemann(2, 10000))[-1]:.10f}')
print(f'π²/6  = {np.pi**2/6:.10f}')
