# %% [markdown]
# # Applications de l'intégrale
#
# **Module :** `applications_integrals.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch3-integralrechnung'))

# %% [markdown]
# ## Aires, volumes, longueurs d'arc

# %%
from applications_integrals import *
import numpy as np
print(f'Aire cercle R=1: {aire_sous_courbe(np.sin, 0, np.pi):.6f}')
print(f'Volume sphère: {volume_disque(lambda x: np.sqrt(max(0,1-x**2)), -1, 1):.6f}')
