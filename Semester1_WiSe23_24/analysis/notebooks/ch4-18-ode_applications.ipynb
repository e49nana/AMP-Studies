# %% [markdown]
# # Applications des EDO
#
# **Module :** `ode_applications.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch4-ode'))

# %% [markdown]
# ## Pendule, logistique, circuit RC

# %%
from ode_applications import *
import numpy as np
r = pendule_conservation(1, 1, np.pi/3)
print(f'v_max = {r["v_max"]:.4f} m/s')
