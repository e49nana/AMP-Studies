# %% [markdown]
# # Intégrales impropres
#
# **Module :** `improper_integrals.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch3-integralrechnung'))

# %% [markdown]
# ## Bornes infinies et singularités

# %%
from improper_integrals import *
for p in [0.5, 1.0, 1.5, 2.0]:
    exact, conv = p_integrale(p)
    print(f'p={p}: {"converge" if conv else "diverge"}')
