# %% [markdown]
# # Séries de Fourier
#
# **Module :** `fourier_series.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch5-spezielle-funktionen'))

# %% [markdown]
# ## Coefficients, Gibbs, Parseval

# %%
from fourier_series import *
for N in [10, 50, 100]:
    print(f'N={N}: Gibbs max = {mesurer_gibbs(N):.6f}')
