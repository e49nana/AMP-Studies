# %% [markdown]
# # Méthode d'Euler
#
# **Module :** `ode_euler.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch4-ode'))

# %% [markdown]
# ## Euler explicite et implicite

# %%
from ode_euler import *
import numpy as np
for h in [0.5, 0.1, 0.01]:
    t, y = euler_explicite(lambda t,y: -y, 0, 1, 3, h)
    print(f'h={h}: y(3)={y[-1]:.8f} err={abs(y[-1]-np.exp(-3)):.2e}')
