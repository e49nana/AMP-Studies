# %% [markdown]
# # Règle de L'Hôpital
#
# **Module :** `lhopital.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch2-differentialrechnung'))

# %% [markdown]
# ## Formes indéterminées 0/0, ∞/∞

# %%
from lhopital import *
for nom, val, exact in exemples_0_sur_0():
    print(f'{nom:30s} ≈ {val:.6f} (exact: {exact})')
