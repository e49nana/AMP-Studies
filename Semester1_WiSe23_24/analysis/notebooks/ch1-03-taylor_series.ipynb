# %% [markdown]
# # Séries de Taylor
#
# **Module :** `taylor_series.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch1-folgen-reihen'))

# %% [markdown]
# ## Développements et convergence

# %%
from taylor_series import *
import numpy as np
for n in [1, 3, 5, 9]:
    err = np.max(np.abs(np.sin(np.linspace(-2,2,100)) - taylor_sin(np.linspace(-2,2,100), n)))
    print(f'T_{2*n+1} sin : err_max = {err:.2e}')
