# %% [markdown]
# # Suites
#
# **Module :** `sequences.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch1-folgen-reihen'))

# %% [markdown]
# ## Suites arithmétiques, géométriques, Héron

# %%
from sequences import *
import numpy as np
heron = heron_sqrt(2, 1.0, 8)
for k, x in enumerate(heron):
    print(f'x_{k} = {x:.15f}  err = {abs(x-np.sqrt(2)):.2e}')
