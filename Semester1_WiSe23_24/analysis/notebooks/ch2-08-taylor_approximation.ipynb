# %% [markdown]
# # Approximation de Taylor
#
# **Module :** `taylor_approximation.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch2-differentialrechnung'))

# %% [markdown]
# ## Polynôme de Taylor et reste de Lagrange

# %%
from taylor_approximation import *
import numpy as np
for n in range(1,8):
    a, b = approximer_sin(0.5, n)
    print(f'{n} termes: {a:.15f} err={abs(a-np.sin(0.5)):.2e} borne={b:.2e}')
