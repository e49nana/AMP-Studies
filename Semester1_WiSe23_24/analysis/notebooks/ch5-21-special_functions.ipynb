# %% [markdown]
# # Fonctions spéciales
#
# **Module :** `special_functions.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch5-spezielle-funktionen'))

# %% [markdown]
# ## Gamma, Beta, hyperboliques, erf

# %%
from special_functions import *
verifier_gamma_proprietes()
