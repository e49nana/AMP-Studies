# %% [markdown]
# # Primitives
#
# **Module :** `antiderivatives.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch3-integralrechnung'))

# %% [markdown]
# ## Hauptsatz, substitution, parties

# %%
from antiderivatives import *
demo_substitution()
demo_par_parties()
