# %% [markdown]
# # SVD — Décomposition en valeurs singulières
#
# **Cours :** Lineare Algebra für AMP — ch6-anwendungen
#
# **Module :** `svd_intro.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch6-anwendungen'))

# %% [markdown]
# ## $A = U\Sigma V^T$ — la factorisation universelle

# %%
from svd_intro import *
import numpy as np
A = np.array([[3,2,2],[2,3,-2]], dtype=float)
U, s, Vt = svd_from_scratch(A)
print(f'σ = {np.round(s, 4)}')
print(f'rang = {np.sum(s > 1e-10)}')
