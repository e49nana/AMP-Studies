# %% [markdown]
# # Rang matriciel
#
# **Cours :** Lineare Algebra für AMP — ch3-gleichungssysteme
#
# **Module :** `matrix_rank.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch3-gleichungssysteme'))

# %% [markdown]
# ## Rang = nombre de pivots = dim(Image)

# %%
from matrix_rank import *
