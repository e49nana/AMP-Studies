# %% [markdown]
# # Gauss-Jordan et RREF
#
# **Cours :** Lineare Algebra für AMP — ch3-gleichungssysteme
#
# **Module :** `gauss_jordan.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch3-gleichungssysteme'))

# %% [markdown]
# ## Résolution de systèmes linéaires par échelonnement

# %%
from gauss_jordan import *
