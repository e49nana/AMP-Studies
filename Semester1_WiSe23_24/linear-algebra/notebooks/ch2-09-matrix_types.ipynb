# %% [markdown]
# # Types de matrices
#
# **Cours :** Lineare Algebra für AMP — ch2-matrizen
#
# **Module :** `matrix_types.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch2-matrizen'))

# %% [markdown]
# ## Symétrique, orthogonale, définie positive...

# %%
from matrix_types import *
