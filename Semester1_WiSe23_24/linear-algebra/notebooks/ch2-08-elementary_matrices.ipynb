# %% [markdown]
# # Matrices élémentaires
#
# **Cours :** Lineare Algebra für AMP — ch2-matrizen
#
# **Module :** `elementary_matrices.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch2-matrizen'))

# %% [markdown]
# ## Permutation, dilatation, transvection
# Gauss = produit de matrices élémentaires

# %%
from elementary_matrices import *
