# %% [markdown]
# # Sous-espaces — Kern, Bild, Rangsatz
#
# **Cours :** Lineare Algebra für AMP — ch1-vektoren
#
# **Module :** `subspaces.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch1-vektoren'))

# %% [markdown]
# ## Noyau et Image
# $\text{rang}(A) + \dim\text{Kern}(A) = n$

# %%
from subspaces import *
