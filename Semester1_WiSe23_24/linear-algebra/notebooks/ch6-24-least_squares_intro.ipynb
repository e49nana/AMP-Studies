# %% [markdown]
# # Moindres carrés
#
# **Cours :** Lineare Algebra für AMP — ch6-anwendungen
#
# **Module :** `least_squares_intro.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch6-anwendungen'))

# %% [markdown]
# ## Projection orthogonale et régression
# $x^* = (A^TA)^{-1}A^Tb$

# %%
from least_squares_intro import *
import numpy as np
rng = np.random.default_rng(42)
x = np.linspace(0, 10, 30)
y = 2.5*x + 3 + rng.normal(0, 2, 30)
a, b = regression_lineaire(x, y)
print(f'y ≈ {a:.3f} + {b:.3f}x')
