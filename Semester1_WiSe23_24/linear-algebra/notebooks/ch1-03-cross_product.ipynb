# %% [markdown]
# # Produit vectoriel — Aires et Volumes
#
# **Cours :** Lineare Algebra für AMP — ch1-vektoren
#
# **Module :** `cross_product.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch1-vektoren'))

# %% [markdown]
# ## Produit vectoriel (R³ uniquement)
# $u \times v \perp u, v$ et $\|u \times v\| = $ aire du parallélogramme

# %%
from cross_product import *
import numpy as np
u = np.array([1, 0, 0])
v = np.array([0, 1, 0])
print(f'u × v = {np.cross(u, v)}')
