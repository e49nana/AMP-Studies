# %% [markdown]
# # Chaînes de Markov
#
# **Cours :** Lineare Algebra für AMP — ch6-anwendungen
#
# **Module :** `markov_chains.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch6-anwendungen'))

# %% [markdown]
# ## Distribution stationnaire = vecteur propre de $\lambda = 1$

# %%
from markov_chains import *
import numpy as np
P, etats = exemple_meteo()
pi = distribution_stationnaire(P)
print(f'π = {np.round(pi, 4)}')
print(f'Vérif Pπ = π : {np.allclose(P @ pi, pi)}')
