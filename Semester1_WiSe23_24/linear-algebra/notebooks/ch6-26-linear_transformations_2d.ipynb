# %% [markdown]
# # Transformations linéaires 2D
#
# **Cours :** Lineare Algebra für AMP — ch6-anwendungen
#
# **Module :** `linear_transformations_2d.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch6-anwendungen'))

# %% [markdown]
# ## Rotation, réflexion, projection, cisaillement

# %%
from linear_transformations_2d import *
import numpy as np
print(f'Rotation 30° :')
print(np.round(rotation(np.pi/6), 4))

# %% [markdown]
# ## Galerie

# %%
fig = tracer_galerie()
import matplotlib.pyplot as plt
plt.show()
