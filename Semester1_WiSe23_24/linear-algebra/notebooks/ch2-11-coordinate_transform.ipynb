# %% [markdown]
# # Changement de base
#
# **Cours :** Lineare Algebra für AMP — ch2-matrizen
#
# **Module :** `coordinate_transform.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch2-matrizen'))

# %% [markdown]
# ## Matrice de passage
# $[A]_{B_2} = P^{-1}AP$ (similitude)

# %%
from coordinate_transform import *
