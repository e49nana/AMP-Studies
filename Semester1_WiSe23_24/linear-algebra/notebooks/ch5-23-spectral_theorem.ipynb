# %% [markdown]
# # Théorème spectral
#
# **Cours :** Lineare Algebra für AMP — ch5-eigenwerte
#
# **Module :** `spectral_theorem.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch5-eigenwerte'))

# %% [markdown]
# ## $A = Q\Lambda Q^T$ pour $A$ symétrique

# %%
from spectral_theorem import *
