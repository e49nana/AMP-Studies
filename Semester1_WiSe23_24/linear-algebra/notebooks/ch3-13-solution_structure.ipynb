# %% [markdown]
# # Structure des solutions
#
# **Cours :** Lineare Algebra für AMP — ch3-gleichungssysteme
#
# **Module :** `solution_structure.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch3-gleichungssysteme'))

# %% [markdown]
# ## $x = x_{part} + x_{hom}$ (superposition)

# %%
from solution_structure import *
