# %% [markdown]
# # Indépendance linéaire et Base
#
# **Cours :** Lineare Algebra für AMP — ch1-vektoren
#
# **Module :** `linear_independence.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch1-vektoren'))

# %% [markdown]
# ## Indépendance linéaire
# $\alpha_1 v_1 + \cdots + \alpha_k v_k = 0 \Rightarrow \alpha_i = 0$

# %%
from linear_independence import *
