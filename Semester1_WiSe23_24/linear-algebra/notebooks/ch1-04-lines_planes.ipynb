# %% [markdown]
# # Droites et Plans en R³
#
# **Cours :** Lineare Algebra für AMP — ch1-vektoren
#
# **Module :** `lines_planes.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch1-vektoren'))

# %% [markdown]
# ## Droites et plans
# Droite : $r(t) = p + td$, Plan : $n \cdot x = n \cdot p$

# %%
from lines_planes import *
