# %% [markdown]
# # Valeurs propres
#
# **Cours :** Lineare Algebra für AMP — ch5-eigenwerte
#
# **Module :** `eigenvalues.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch5-eigenwerte'))

# %% [markdown]
# ## $Av = \lambda v$ — polynôme caractéristique

# %%
from eigenvalues import *
