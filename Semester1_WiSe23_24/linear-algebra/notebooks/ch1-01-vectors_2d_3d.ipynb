# %% [markdown]
# # Vecteurs en 2D et 3D
#
# **Cours :** Lineare Algebra für AMP — ch1-vektoren
#
# **Module :** `vectors_2d_3d.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch1-vektoren'))

# %% [markdown]
# ## Opérations fondamentales sur les vecteurs

# %%
from vectors_2d_3d import *
import numpy as np
v = np.array([1, 2, 3])
w = np.array([4, -1, 2])
print(f'v + w = {v + w}')
print(f'3v = {3*v}')

# %% [markdown]
# ## Visualisation

# %%
import matplotlib.pyplot as plt
if hasattr(globals().get('tracer_vecteurs', None), '__call__'):
    tracer_vecteurs()
    plt.show()
