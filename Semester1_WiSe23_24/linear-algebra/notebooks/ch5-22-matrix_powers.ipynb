# %% [markdown]
# # Puissances de matrices
#
# **Cours :** Lineare Algebra für AMP — ch5-eigenwerte
#
# **Module :** `matrix_powers.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch5-eigenwerte'))

# %% [markdown]
# ## Markov, stabilité, Fibonacci via $A^k$

# %%
from matrix_powers import *
