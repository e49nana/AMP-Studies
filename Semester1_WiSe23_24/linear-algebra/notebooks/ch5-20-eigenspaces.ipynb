# %% [markdown]
# # Espaces propres
#
# **Cours :** Lineare Algebra für AMP — ch5-eigenwerte
#
# **Module :** `eigenspaces.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch5-eigenwerte'))

# %% [markdown]
# ## $\text{Kern}(A - \lambda I)$, multiplicités $m_a$ vs $m_g$

# %%
from eigenspaces import *
