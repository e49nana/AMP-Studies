# %% [markdown]
# # Règle de Cramer
#
# **Cours :** Lineare Algebra für AMP — ch4-determinanten
#
# **Module :** `cramer.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch4-determinanten'))

# %% [markdown]
# ## $x_i = \det(A_i)/\det(A)$ — élégant mais $O(n^4)$

# %%
from cramer import *
