# %% [markdown]
# # Diagonalisation
#
# **Cours :** Lineare Algebra für AMP — ch5-eigenwerte
#
# **Module :** `diagonalization.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch5-eigenwerte'))

# %% [markdown]
# ## $A = PDP^{-1}$ → $A^k = PD^kP^{-1}$

# %%
from diagonalization import *
