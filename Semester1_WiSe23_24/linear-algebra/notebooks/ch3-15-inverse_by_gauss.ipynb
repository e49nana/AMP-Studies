# %% [markdown]
# # Inverse par Gauss-Jordan
#
# **Cours :** Lineare Algebra für AMP — ch3-gleichungssysteme
#
# **Module :** `inverse_by_gauss.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch3-gleichungssysteme'))

# %% [markdown]
# ## $[A|I] \to [I|A^{-1}]$

# %%
from inverse_by_gauss import *
