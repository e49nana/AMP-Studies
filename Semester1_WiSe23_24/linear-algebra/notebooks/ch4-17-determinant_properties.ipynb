# %% [markdown]
# # Propriétés du déterminant
#
# **Cours :** Lineare Algebra für AMP — ch4-determinanten
#
# **Module :** `determinant_properties.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch4-determinanten'))

# %% [markdown]
# ## $\det(AB) = \det(A)\det(B)$, interprétation géométrique

# %%
from determinant_properties import *
