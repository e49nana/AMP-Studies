# %% [markdown]
# # Applications linéaires
#
# **Cours :** Lineare Algebra für AMP — ch2-matrizen
#
# **Module :** `linear_maps.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch2-matrizen'))

# %% [markdown]
# ## $f$ linéaire $\Leftrightarrow$ matrice $A$ telle que $f(x) = Ax$

# %%
from linear_maps import *
