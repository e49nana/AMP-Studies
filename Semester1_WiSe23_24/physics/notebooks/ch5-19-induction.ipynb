# %% [markdown]
# # Induction
#
# **Module :** `induction.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch5-elektrodynamik'))

# %% [markdown]
# ## Faraday, générateur, transformateur

# %%
from induction import *
for N2 in [50,100,200,1000]:
    r=transformateur(230,100,N2,1)
    print(f'N2={N2}: V2={r["V2"]:.1f}V')
