# %% [markdown]
# # Champ électrique
#
# **Module :** `electric_field.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch4-elektrostatik'))

# %% [markdown]
# ## Lignes de champ, dipôle

# %%
from electric_field import *
