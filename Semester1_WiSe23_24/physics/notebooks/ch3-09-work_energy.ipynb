# %% [markdown]
# # Travail et énergie
#
# **Module :** `work_energy.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch3-energie'))

# %% [markdown]
# ## W = ∫F·ds, théorème W-E

# %%
from work_energy import *
