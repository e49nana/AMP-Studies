# %% [markdown]
# # Lois de Newton
#
# **Module :** `newton_laws.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch2-dynamik'))

# %% [markdown]
# ## F = ma, plan incliné, Atwood

# %%
from newton_laws import *
import numpy as np
for t in [15,30,45]:
    r=plan_incline(10,np.radians(t),0.2)
    print(f'θ={t}°: a={r["a"]:.2f} m/s²')
