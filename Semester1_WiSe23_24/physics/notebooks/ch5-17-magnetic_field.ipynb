# %% [markdown]
# # Champ magnétique
#
# **Module :** `magnetic_field.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch5-elektrodynamik'))

# %% [markdown]
# ## Biot-Savart, Lorentz, cyclotron

# %%
from magnetic_field import *
