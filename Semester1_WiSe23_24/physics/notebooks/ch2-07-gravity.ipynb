# %% [markdown]
# # Gravitation
#
# **Module :** `gravity.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch2-dynamik'))

# %% [markdown]
# ## Newton, Kepler, orbites

# %%
from gravity import *
verifier_kepler_3([('Terre',1,1),('Mars',1.524,1.881),('Jupiter',5.203,11.86)])
