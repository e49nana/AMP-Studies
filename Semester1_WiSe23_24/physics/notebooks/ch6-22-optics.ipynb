# %% [markdown]
# # Optique géométrique
#
# **Module :** `optics.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch6-wellen-optik'))

# %% [markdown]
# ## Snell, lentilles, fibres

# %%
from optics import *
import numpy as np
for n1,n2,th in [(1,1.5,30),(1.5,1,30),(1.5,1,42)]:
    th2=snell(n1,np.radians(th),n2)
    print(f'n1={n1},n2={n2},θ1={th}°: θ2={"réflexion totale" if th2 is None else f"{np.degrees(th2):.1f}°"}')
