# %% [markdown]
# # Puissance et rendement
#
# **Module :** `power_efficiency.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch3-energie'))

# %% [markdown]
# ## P = F·v, machines simples

# %%
from power_efficiency import *
for v in [15,25,35]:
    r=puissance_cycliste(80,v/3.6,0)
    print(f'{v}km/h: P={r["P_total"]:.0f}W')
