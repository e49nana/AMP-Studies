# %% [markdown]
# # Ondes EM
#
# **Module :** `electromagnetic_waves.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch5-elektrodynamik'))

# %% [markdown]
# ## c = 1/√(μ₀ε₀), spectre

# %%
from electromagnetic_waves import *
print(f'c = {vitesse_lumiere():.6e} m/s')
afficher_spectre()
