# %% [markdown]
# # Loi de Coulomb
#
# **Module :** `coulomb.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch4-elektrostatik'))

# %% [markdown]
# ## F = kq₁q₂/r²

# %%
from coulomb import *
c=comparer_gravitationnelle_electrique()
print(f'F_elec/F_grav = {c["ratio"]:.2e}')
