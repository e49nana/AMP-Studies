# %% [markdown]
# # Potentiel électrique
#
# **Module :** `electric_potential.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch4-elektrostatik'))

# %% [markdown]
# ## V = kQ/r, E = -∇V

# %%
from electric_potential import *
