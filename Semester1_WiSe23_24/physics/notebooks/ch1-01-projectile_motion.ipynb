# %% [markdown]
# # Tir oblique
#
# **Module :** `projectile_motion.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch1-kinematik'))

# %% [markdown]
# ## Trajectoire parabolique

# %%
from projectile_motion import *
for deg in [15,30,45,60,75]:
    a=__import__('numpy').radians(deg)
    print(f'{deg}°: R={portee(20,a):.1f}m H={hauteur_max(20,a):.1f}m')
