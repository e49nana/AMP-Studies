# %% [markdown]
# # Mouvement circulaire
#
# **Module :** `circular_motion.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch1-kinematik'))

# %% [markdown]
# ## MCU et satellites

# %%
from circular_motion import *
for h in [200e3, 400e3, 35786e3]:
    o=orbite_satellite(h)
    print(f'h={h/1e3:.0f}km: v={o["vitesse"]:.0f}m/s T={o["periode_h"]:.2f}h')
