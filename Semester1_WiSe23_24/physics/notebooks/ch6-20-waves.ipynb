# %% [markdown]
# # Ondes mécaniques
#
# **Module :** `waves.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch6-wellen-optik'))

# %% [markdown]
# ## Propagation, stationnaires, battements

# %%
from waves import *
