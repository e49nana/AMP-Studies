# %% [markdown]
# # Oscillations
#
# **Module :** `oscillations.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch2-dynamik'))

# %% [markdown]
# ## Harmonique, amorti, forcé, résonance

# %%
from oscillations import *
for g in [0,1,5,8]:
    disc=g**2-25
    r='sous-amorti' if disc<0 else 'critique' if abs(disc)<0.1 else 'sur-amorti'
    print(f'γ={g}: {r}')
