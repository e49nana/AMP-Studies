# %% [markdown]
# # Mouvement relatif
#
# **Module :** `relative_motion.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch1-kinematik'))

# %% [markdown]
# ## Galilée, rivière, vent

# %%
from relative_motion import *
