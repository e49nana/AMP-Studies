# %% [markdown]
# # Collisions
#
# **Module :** `collisions.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch2-dynamik'))

# %% [markdown]
# ## Élastique, inélastique, 2D

# %%
from collisions import *
cas_speciaux()
