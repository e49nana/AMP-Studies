# %% [markdown]
# # Interférence et diffraction
#
# **Module :** `interference.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch6-wellen-optik'))

# %% [markdown]
# ## Young, diffraction, réseau

# %%
from interference import *
