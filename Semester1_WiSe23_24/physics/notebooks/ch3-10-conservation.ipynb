# %% [markdown]
# # Conservation de l'énergie
#
# **Module :** `conservation.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch3-energie'))

# %% [markdown]
# ## E_mec = const, diagrammes de potentiel

# %%
from conservation import *
import numpy as np
r = pendule_conservation(1, 1, np.pi/3)
print(f'v_max = {r["v_max"]:.4f} m/s')
