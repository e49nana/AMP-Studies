# %% [markdown]
# # Circuits
#
# **Module :** `circuits.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch5-elektrodynamik'))

# %% [markdown]
# ## RC, RL, RLC

# %%
from circuits import *
for R in [5,20,63,100]:
    print(f'R={R}Ω: {rlc_regime(R, 0.1, 1e-4)}')
