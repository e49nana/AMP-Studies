# %% [markdown]
# # Courbes paramétriques
#
# **Module :** `parametric_curves.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch1-kinematik'))

# %% [markdown]
# ## Cycloïde, Lissajous, spirographe

# %%
from parametric_curves import *
fig = tracer_galerie()
import matplotlib.pyplot as plt; plt.show()
