# %% [markdown]
# # Loi de Gauss
#
# **Module :** `gauss_law.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch4-elektrostatik'))

# %% [markdown]
# ## Φ = Q/ε₀, symétries

# %%
from gauss_law import *
