# %% [markdown]
# # Estimation — MLE, Intervalles de confiance
#
# **Cours :** Stochastik für AMP — ch4-statistik
#
# **Module :** `estimation.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch4-statistik'))

# %% [markdown]
# ## 1. MLE et biais

# %%
from estimation import *
b = demo_biais_variance()
print(f"E[σ̂²_MLE] = {b['E[σ²_MLE]']:.4f} (biaisé: {b['biais MLE']:.4f})")
print(f"E[s²]      = {b['E[s²]']:.4f} (non biaisé: {b['biais s²']:.6f})")

# %% [markdown]
# ## 2. IC : Z vs t

# %%
import numpy as np
rng = np.random.default_rng(42)
data = rng.normal(50, 10, 36)
print(f"IC_Z (σ=10) : {ic_z(data, 10, 0.05)}")
print(f"IC_t        : {ic_t(data, 0.05)}")

# %% [markdown]
# ## 3. Taille d'échantillon

# %%
for marge in [1, 2, 5]:
    print(f"σ=10, marge={marge} : n ≥ {taille_echantillon_mu(10, marge)}")
print(f"Proportion, marge=3% : n ≥ {taille_echantillon_proportion(0.03)}")

# %% [markdown]
# ## 4. Visualisation

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 3, figsize=(16, 4))
tracer_ic_couverture(ax=axes[0])
tracer_taille_echantillon(ax=axes[1])
tracer_convergence_estimateur(ax=axes[2])
plt.tight_layout(); plt.show()
