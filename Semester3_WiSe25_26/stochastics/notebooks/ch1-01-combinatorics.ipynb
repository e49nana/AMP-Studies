# %% [markdown]
# # Combinatoire — Permutations, Combinaisons, Pascal
#
# **Cours :** Stochastik für AMP — ch1-grundlagen
#
# **Module :** `combinatorics.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch1-grundlagen'))

# %% [markdown]
# ## 1. Factorielles et dénombrement

# %%
from combinatorics import *
import numpy as np

print(f"10! = {factorielle(10)}")
print(f"A(10,3) = {arrangements_count(10, 3)}")
print(f"C(10,3) = {combinaisons_count(10, 3)}")
print(f"C_rep(5,3) = {combinaisons_repetition(5, 3)}")

# %% [markdown]
# ## 2. Triangle de Pascal

# %%
afficher_pascal(8)

# %% [markdown]
# ## 3. Formule du binôme
# $(a+b)^n = \sum C(n,k) a^k b^{n-k}$

# %%
for n in [2, 5, 10]:
    print(f"(3+2)^{n} = {(3+2)**n}, binôme = {int(binome_expansion(3, 2, n))}")

# %% [markdown]
# ## 4. Dérangements
# $D_n/n! \to 1/e$

# %%
for n in range(1, 8):
    print(f"D_{n} = {derangements(n):>6} / {factorielle(n):>6} = {derangements(n)/factorielle(n):.4f}")

# %% [markdown]
# ## 5. Visualisation

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
tracer_binomial_coefficients(ax=axes[0])
tracer_derangements(ax=axes[1])
plt.tight_layout(); plt.show()
