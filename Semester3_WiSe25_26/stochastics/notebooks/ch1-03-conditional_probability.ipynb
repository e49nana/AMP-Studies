# %% [markdown]
# # Probabilités conditionnelles — Monty Hall, Anniversaires, Bayes itératif
#
# **Cours :** Stochastik für AMP — ch1-grundlagen
#
# **Module :** `conditional_probability.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch1-grundlagen'))

# %% [markdown]
# ## 1. Problème de Monty Hall
# Changer gagne $2/3$ du temps !

# %%
from conditional_probability import *
r = monty_hall_simulation(100_000)
print(f"Garder  : {r['garder']:.4f} (théo: 1/3)")
print(f"Changer : {r['changer']:.4f} (théo: 2/3)")

# %% [markdown]
# ## 2. Paradoxe des anniversaires
# $n = 23$ suffit pour $P > 50\%$

# %%
for n in [10, 23, 30, 50, 70]:
    print(f"n={n:>2} : P(collision) = {prob_anniversaire_commun(n):.4f}")
print(f"Seuil 50% : n = {seuil_anniversaire(0.5)}")

# %% [markdown]
# ## 3. Mise à jour bayésienne
# Pièce biaisée ? 7 faces, 3 piles.

# %%
posteriors = bayes_iteratif(0.5, [(0.8, 0.5)]*7 + [(0.2, 0.5)]*3)
for i, p in enumerate(posteriors):
    print(f"Après {i:>2} obs : P(biaisée) = {p:.4f}")

# %% [markdown]
# ## 4. Visualisation

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 3, figsize=(16, 4))
tracer_anniversaire(ax=axes[0])
tracer_monty_hall(ax=axes[1])
tracer_bayes_iteratif(ax=axes[2])
plt.tight_layout(); plt.show()
