# %% [markdown]
# # Tests d'hypothèses — Z, t, χ², Puissance
#
# **Cours :** Stochastik für AMP — ch4-statistik
#
# **Module :** `hypothesis_testing.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch4-statistik'))

# %% [markdown]
# ## 1. Test Z et t

# %%
from hypothesis_testing import *
import numpy as np
rng = np.random.default_rng(42)
data = rng.normal(52, 10, 50)
r_z = test_z(data, 50, 10)
r_t = test_t_1echantillon(data, 50)
print(f"Z-test : Z = {r_z.statistique:.4f}, p = {r_z.p_value:.4f} → {r_z.conclusion}")
print(f"t-test : t = {r_t.statistique:.4f}, p = {r_t.p_value:.4f} → {r_t.conclusion}")

# %% [markdown]
# ## 2. χ² d'indépendance

# %%
tableau = np.array([[30, 10], [15, 25]])
r = test_chi2_independance(tableau)
print(f"χ² = {r.statistique:.2f}, p = {r.p_value:.4f} → {r.conclusion}")

# %% [markdown]
# ## 3. Puissance

# %%
for n in [10, 30, 100, 300]:
    pw = puissance_test_z(0, 0.5, 1, n)
    print(f"n={n:>3}, effet=0.5σ : puissance = {pw:.4f}")

# %% [markdown]
# ## 4. Visualisation

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 3, figsize=(16, 4))
tracer_test_z_visuel(data, 50, 10, ax=axes[0])
tracer_puissance(ax=axes[1])
tracer_p_value_interpretation(ax=axes[2])
plt.tight_layout(); plt.show()
