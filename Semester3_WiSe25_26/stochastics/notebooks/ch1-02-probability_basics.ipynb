# %% [markdown]
# # Probabilités de base — Kolmogorov, Bayes
#
# **Cours :** Stochastik für AMP — ch1-grundlagen
#
# **Module :** `probability_basics.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch1-grundlagen'))

# %% [markdown]
# ## 1. Exemples avec des dés

# %%
from probability_basics import *
exemple_des()

# %% [markdown]
# ## 2. Urne — avec et sans remise

# %%
exemple_urne()

# %% [markdown]
# ## 3. Théorème de Bayes — test médical
# Même un bon test a un faible PPV si la prévalence est basse.

# %%
exemple_bayes()

# %% [markdown]
# ## 4. Visualisation

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
tracer_somme_des(ax=axes[0])
tracer_bayes_prevalence(ax=axes[1])
plt.tight_layout(); plt.show()
