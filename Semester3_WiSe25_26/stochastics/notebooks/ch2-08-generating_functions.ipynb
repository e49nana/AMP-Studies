# %% [markdown]
# # Fonctions génératrices — Moments, Somme de v.a.
#
# **Cours :** Stochastik für AMP — ch2-diskrete-verteilungen
#
# **Module :** `generating_functions.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch2-diskrete-verteilungen'))

# %% [markdown]
# ## 1. Moments par FGP
# $G'(1) = E[X]$, $G''(1) + G'(1) - (G'(1))^2 = \text{Var}(X)$

# %%
from generating_functions import *
for nom, G, E_t, V_t in [("B(10,0.3)", lambda s: fgp_binomiale(s, 10, 0.3), 3, 2.1),
                           ("Po(5)", lambda s: fgp_poisson(s, 5), 5, 5)]:
    m = moments_depuis_fgp(G)
    print(f"{nom}: E={m['E[X]']:.4f} (théo:{E_t}), Var={m['Var(X)']:.4f} (théo:{V_t})")

# %% [markdown]
# ## 2. Somme de Poisson
# $Po(\lambda_1) + Po(\lambda_2) = Po(\lambda_1 + \lambda_2)$

# %%
demo_somme_poisson()

# %% [markdown]
# ## 3. Visualisation

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
tracer_fgp(ax=axes[0])
tracer_somme_verification(ax=axes[1])
plt.tight_layout(); plt.show()
