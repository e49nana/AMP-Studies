# %% [markdown]
# # DFT et FFT
#
# **Module :** `dft_fft.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch4-integraltransformationen'))

# %% [markdown]
# ## DFT O(N²) vs FFT O(N log N)

# %%
from dft_fft import *
import numpy as np
x = np.array([1,2,3,4], dtype=float)
print(f'DFT = {np.round(dft(x), 4)}')
print(f'FFT = {np.round(fft_cooley_tukey(x), 4)}')
