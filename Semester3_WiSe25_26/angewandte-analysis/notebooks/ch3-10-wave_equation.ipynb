# %% [markdown]
# # Équation des ondes
#
# **Module :** `wave_equation.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch3-pde'))

# %% [markdown]
# ## Schéma centré, CFL, d'Alembert

# %%
from wave_equation import *
cfl = condition_cfl(1.0, 0.01, 0.008)
print(f'CFL: r={cfl["r"]:.2f}, stable={cfl["stable"]}')
