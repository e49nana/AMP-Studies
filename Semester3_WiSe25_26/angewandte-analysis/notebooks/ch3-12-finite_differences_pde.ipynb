# %% [markdown]
# # Différences finies — synthèse
#
# **Module :** `finite_differences_pde.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch3-pde'))

# %% [markdown]
# ## Classification, Crank-Nicolson, Von Neumann

# %%
from finite_differences_pde import *
for nom, A, B, C in [('Laplace',1,0,1),('Chaleur',1,0,0),('Ondes',1,0,-1)]:
    print(f'{nom}: {classifier_edp(A,B,C)}')
