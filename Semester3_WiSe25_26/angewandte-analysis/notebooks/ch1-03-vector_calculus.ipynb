# %% [markdown]
# # Calcul vectoriel
#
# **Module :** `vector_calculus.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch1-mehrdimensionale-analysis'))

# %% [markdown]
# ## div, rot, Laplacien

# %%
from vector_calculus import *
Fx, Fy = lambda x,y: x, lambda x,y: y
print(f'div(x,y) = {divergence_2d(Fx, Fy, 1, 1):.4f} (exact: 2)')
