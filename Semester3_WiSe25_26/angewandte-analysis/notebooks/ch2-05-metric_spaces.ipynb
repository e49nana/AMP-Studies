# %% [markdown]
# # Espaces métriques
#
# **Module :** `metric_spaces.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch2-funktionalanalysis'))

# %% [markdown]
# ## Métriques, Cauchy, point fixe

# %%
from metric_spaces import *
import numpy as np
T = lambda x: np.array([np.cos(x[0])])
r = point_fixe_banach(T, np.array([0.0]), d_euclidienne)
print(f'Point fixe cos: {r["point_fixe"][0]:.10f}')
