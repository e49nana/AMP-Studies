# %% [markdown]
# # Espaces de Hilbert
#
# **Module :** `inner_product_spaces.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch2-funktionalanalysis'))

# %% [markdown]
# ## Cauchy-Schwarz, projection, Gram-Schmidt

# %%
from inner_product_spaces import *
import numpy as np
v1 = np.array([1,1,0.])
v2 = np.array([1,0,1.])
v3 = np.array([0,1,1.])
base = gram_schmidt([v1,v2,v3])
for i, e in enumerate(base):
    print(f'e_{i+1} = {np.round(e, 4)}')
