# %% [markdown]
# # Dérivées partielles
#
# **Module :** `partial_derivatives.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch1-mehrdimensionale-analysis'))

# %% [markdown]
# ## Gradient, Hessienne, points critiques

# %%
from partial_derivatives import *
import numpy as np
f = lambda x,y: x**2 + 2*y**2 - x*y
g = gradient(f, np.array([1.0, 1.0]))
print(f'∇f(1,1) = {np.round(g, 4)}')
