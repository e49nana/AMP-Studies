# %% [markdown]
# # Équation de la chaleur
#
# **Module :** `heat_equation.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch3-pde'))

# %% [markdown]
# ## FTCS, BTCS, stabilité

# %%
from heat_equation import *
import numpy as np
L, nx = 1.0, 51
x = np.linspace(0, L, nx)
u0 = np.sin(np.pi*x/L)
u = heat_explicite(u0, 0.01, L/(nx-1), 0.0004, 2000)
print(f'u(0.5, t_final) = {u[-1, nx//2]:.6f}')
