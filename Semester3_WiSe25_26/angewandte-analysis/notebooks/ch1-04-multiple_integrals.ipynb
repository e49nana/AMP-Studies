# %% [markdown]
# # Intégrales multiples
#
# **Module :** `multiple_integrals.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch1-mehrdimensionale-analysis'))

# %% [markdown]
# ## Doubles, triples, coordonnées

# %%
from multiple_integrals import *
import numpy as np
A = integrale_polaire(lambda r,th: 1, (0, 1))
print(f'Aire disque R=1: {A:.6f} (exact: π = {np.pi:.6f})')
