# %% [markdown]
# # Transformée de Fourier
#
# **Module :** `fourier_transform.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch4-integraltransformationen'))

# %% [markdown]
# ## TF continue, convolution, Parseval

# %%
from fourier_transform import *
import numpy as np
omega = np.linspace(-10,10,100)
F_num = fourier_transform_num(lambda t: np.exp(-t**2/2), omega)
F_exact = tf_gaussienne(omega, 1)
print(f'||F_num - F_exact|| = {np.max(np.abs(F_num-F_exact)):.2e}')
