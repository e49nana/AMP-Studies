# %% [markdown]
# # Optimisation multivariable
#
# **Module :** `multivariable_optimization.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch1-mehrdimensionale-analysis'))

# %% [markdown]
# ## GD, Newton, Lagrange

# %%
from multivariable_optimization import *
import numpy as np
rosenbrock = lambda v: (1-v[0])**2 + 100*(v[1]-v[0]**2)**2
r = newton_multivariable(rosenbrock, np.array([-1.0, 1.0]))
print(f'x* = {np.round(r.x, 6)}, {r.iterations} it.')
