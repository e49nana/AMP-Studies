# %% [markdown]
# # Traitement du signal
#
# **Module :** `signal_processing.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch4-integraltransformationen'))

# %% [markdown]
# ## Filtrage, fenêtrage, spectrogramme

# %%
from signal_processing import *
import numpy as np
rng = np.random.default_rng(42)
t = np.arange(2048)*0.001
signal = np.sin(2*np.pi*10*t) + 0.8*rng.standard_normal(2048)
filtre = filtre_passe_bas(signal, 0.001, 20)
print(f'RMSE après filtrage: {np.sqrt(np.mean((filtre-np.sin(2*np.pi*10*t))**2)):.4f}')
