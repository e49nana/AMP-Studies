# %% [markdown]
# # Transformée de Laplace
#
# **Module :** `laplace_transform.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch4-integraltransformationen'))

# %% [markdown]
# ## TL, résolution d'EDO, pôles

# %%
from laplace_transform import *
import numpy as np
for R in [5,20,100]:
    p = poles([0.1*1e-4, R*1e-4, 1])
    print(f'R={R}: pôles={np.round(p,1)}, stable={est_stable(p)}')
