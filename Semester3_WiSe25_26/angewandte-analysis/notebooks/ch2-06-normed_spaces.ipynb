# %% [markdown]
# # Espaces normés
#
# **Module :** `normed_spaces.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch2-funktionalanalysis'))

# %% [markdown]
# ## Normes p, équivalence, opérateurs

# %%
from normed_spaces import *
import numpy as np
x = np.array([1,-2,3])
for p in [1,2,np.inf]:
    v = norme_p(x,p) if p != np.inf else norme_inf(x)
    print(f'||x||_{p} = {v:.4f}')
