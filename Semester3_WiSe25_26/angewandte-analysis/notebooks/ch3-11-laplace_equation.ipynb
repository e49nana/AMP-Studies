# %% [markdown]
# # Laplace/Poisson 2D
#
# **Module :** `laplace_equation.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch3-pde'))

# %% [markdown]
# ## Jacobi, Gauss-Seidel

# %%
from laplace_equation import *
u, k = laplace_jacobi(41, 41, {'top':100,'bottom':0,'left':0,'right':0})
print(f'{k} itérations, u(centre) = {u[20,20]:.4f}')
