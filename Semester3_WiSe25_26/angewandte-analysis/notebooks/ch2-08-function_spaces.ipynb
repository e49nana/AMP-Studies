# %% [markdown]
# # Espaces de fonctions
#
# **Module :** `function_spaces.py`

# %%
import sys, os
sys.path.insert(0, os.path.join('..', 'code', 'ch2-funktionalanalysis'))

# %% [markdown]
# ## C[a,b] vs L², convergences

# %%
from function_spaces import *
demo_convergence_types()
